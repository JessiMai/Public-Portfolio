# %% [markdown]
# # Testing Notebook for Functions

# %% [markdown]
# ### Imports

# %%
import SimulationFunctions
import PlottingFunctions
import numpy as np
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [1] in <cell line: 2>
#     import PlottingFunctions
#
#   File ~\Jess Code\Public-Portfolio\PlottingFunctions.py:12
#     match dataDict['dataType']:
#           ^
# SyntaxError: invalid syntax

# %%
dataDict = {
            'plotType' : ['LiveLine', 'LiveColour', 'PrintColour'],
            'measurementType': ['FrequencySweep', 'FrequencyVoltageSweep', 'FrequencyVoltageSweep'],
            'data': {
                'frequency': [np.arange(2e9, 2.7e9, 0.01e9), np.arange(2e9, 2.7e9, 0.01e9), np.arange(2e9, 2.7e9, 0.01e9)],
                'Amplitude': []
            }
        }
